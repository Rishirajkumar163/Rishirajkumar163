# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
NBAdata=pd.read_csv("NBA_data.csv")

# %%
NBAdata
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
NBAdata.describe()
# Out:
#               Age       Games  Minutes Played  True Shooting(%)  \
# count  497.000000  497.000000      495.000000        494.000000
# mean    25.623742   18.456740      416.492929          0.538939
# std      4.054229    8.311394      297.543620          0.130360
# min     19.000000    1.000000        2.000000          0.000000
# 25%     22.000000   12.000000      127.000000          0.500000
# 50%     25.000000   20.000000      417.000000          0.556000
# 75%     28.000000   26.000000      665.500000          0.607000
# max     37.000000   30.000000     1101.000000          1.500000
#
#        Threepoint Attempt rate  Free throw attempt rate  \
# count               495.000000               495.000000
# mean                  0.406362                 0.274804
# std                   0.234207                 0.270650
# min                   0.000000                 0.000000
# 25%                   0.255000                 0.142000
# ...

# %%
NBAdata.head()
# Out:
#               Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0   Precious Achiuwa       PF   21     28           408.0             0.599
# 1       Jaylen Adams       PG   24      6            17.0             0.125
# 2       Steven Adams        C   27     27           760.0             0.592
# 3        Bam Adebayo        C   23     26           873.0             0.641
# 4  LaMarcus Aldridge        C   35     18           480.0             0.542
#
#    Threepoint Attempt rate  Free throw attempt rate  Player Efficiency Rating
# 0                    0.000                    0.541                      15.1
# 1                    0.250                    0.000                      -6.9
# 2                      NaN                    0.397                      15.9
# 3                    0.015                    0.469                      22.7
# 4                    0.298                    0.093                      15.2

# %%
NBAdata.tail()
# Out:
#              Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 492    Delon Wright       SG   28     28           823.0             0.559
# 493  Thaddeus Young       PF   32     23           592.0             0.597
# 494      Trae Young       PG   22     26           901.0             0.598
# 495     Cody Zeller        C   28     15           361.0             0.569
# 496     Ivica Zubac        C   23     30           586.0             0.722
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 492                    0.298                    0.346
# 493                    0.104                    0.169
# 494                    0.349                    0.577
# 495                    0.133                    0.242
# 496                    0.007                    0.500
#
#      Player Efficiency Rating
# 492                      16.6
# 493                      18.5
# 494                      22.9
# 495                      18.2
# 496                      20.5

# %%
NBAdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    497 non-null    object
#  1   Position                  497 non-null    object
#  2   Age                       497 non-null    int64
#  3   Games                     497 non-null    int64
#  4   Minutes Played            495 non-null    float64
#  5   True Shooting(%)          494 non-null    float64
#  6   Threepoint Attempt rate   495 non-null    float64
#  7   Free throw attempt rate   495 non-null    float64
#  8   Player Efficiency Rating  497 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 35.1+ KB

# %%
print(NBAdata.loc[0:496,['Position','Age']])
# Out:
#     Position  Age
# 0         PF   21
# 1         PG   24
# 2          C   27
# 3          C   23
# 4          C   35
# ..       ...  ...
# 492       SG   28
# 493       PF   32
# 494       PG   22
# 495        C   28
# 496        C   23
#
# [497 rows x 2 columns]

# %%
print(NBAdata["Position"])
# Out:
# 0      PF
# 1      PG
# 2       C
# 3       C
# 4       C
#        ..
# 492    SG
# 493    PF
# 494    PG
# 495     C
# 496     C
# Name: Position, Length: 497, dtype: object

# %%
sns.relplot(x='Player',y='Player Efficiency Rating',data=NBAdata)

# %%
sns.regplot(x='Position',y='Player Efficiency Rating',data=NBAdata)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18980/1736977130.py in <module>
# ----> 1 sns.regplot(x='Position',y='Player Efficiency Rating',data=NBAdata)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
#     862     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...
